# %%
# 1
num = int(input("학생 번호: "))
leader_num = ((num-1) // 10 * 10) + 1
print(leader_num)
# Out:
# 31

# %%
# 2
try:
    num = int(input("숫자를 입력하세요"))
    if num % 2 == 0:
        print("짝수")
    else:
        print("홀수")
except ValueError as e:
    print("숫자만 입력하세요")
    # print(e)
# Out:
# 숫자만 입력하세요
